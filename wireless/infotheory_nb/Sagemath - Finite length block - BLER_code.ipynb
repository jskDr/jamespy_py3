# %% [markdown]
# # Asymptotic Performance of Finte Length Block Code

# %% [markdown]
# ## BLER

# %%
def get_C(rho_0, z_range=[-10,10], fig_flag=True):
    rho, z = var('rho, z')
    c(rho,z) = 1/sqrt(2*pi) * e^(-z^2/2)*(1 - log(1+e^(-2*rho+2*z*sqrt(rho)),2))
    pretty_print('c:', c)
    if fig_flag:
        p1 = plot(c(rho_0,z),z,z_range[0],z_range[1])
        show(p1)
    C = integrate(c(rho=rho_0),(z,z_range[0],z_range[1]))
    return C.n()

# %%
get_C(1)
# Out:
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 0.485944154132935

# %%
P = var('P')
C = (1/2)*log(1+P,2)
C
# Out:
# 1/2*log(P + 1)/log(2)

# %%
C(1)
# Out:
# 1/2

# %%
def get_V(rho_0, z_range=[-10,10], fig_flag=True):
    rho, z = var('rho, z')
    C = get_C(rho_0,z_range=z_range)
    v(rho,z) = 1/sqrt(2*pi) * e^(-z^2/2)*(1 - log(1 + e^(-2*rho + 2*z*sqrt(rho)),2) - C)^2
    pretty_print('v:', v)
    if fig_flag:
        p1 = plot(v(rho_0,z),z,z_range[0],z_range[1])
        show(p1)
    V = integrate(v(rho=rho_0),(z,z_range[0],z_range[1]))
    return V.n()

# %%
get_V(1)
# Out:
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'v:' (rho, z) |--> 1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 0.514055845867065)^2*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 0.659680834305077

# %%
def get_epsilon(EbNo_dB, R_0): 
    LN, t = var('LN t')
    EbNo = 10^(EbNo_dB/10)
    rho_0 = 2*R_0*EbNo
    q(t) = (1/sqrt(2*pi))*e^((-t^2)/2)
    Q(x) = integral(q(t),(t,x,oo))
    ep = (LN*(get_C(rho_0) - R_0) + (1/2)*log(LN,2))/sqrt(LN*get_V(rho_0))
    pretty_print('ep:', ep)
    EP = Q(ep)
    pretty_print('EP:', EP)
    return EP

# %%
epsilon_3dB_1p2 = get_epsilon(3, 1/2)
#epsilon_3dB_1p2(128)
# Out:
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'v:' (rho, z) |--> 1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 0.279339111333940)^2*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'ep:' -0.684126510564732*(-0.441321777332121*LN - log(LN)/log(2))/sqrt(LN)
# 'EP:' -1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(-0.342063255282366*sqrt(2)*(-0.441321777332121*LN - log(LN)/log(2))/sqrt(LN)) - sqrt(2)*sqrt(pi))/sqrt(pi)

# %%
epsilon_3dB_1p2(LN=128)
# Out:
# 0.0000617391099148046

# %%
BLER = [get_epsilon(EbNo_dB, 1/2)(LN=128) for EbNo_dB in range(1,3)]
# Out:
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'v:' (rho, z) |--> 1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 0.437211862241349)^2*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'ep:' -0.620938234882967*(-0.125576275517301*LN - log(LN)/log(2))/sqrt(LN)
# 'EP:' -1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(-0.310469117441483*sqrt(2)*(-0.125576275517301*LN - log(LN)/log(2))/sqrt(LN)) - sqrt(2)*sqrt(pi))/sqrt(pi)
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'v:' (rho, z) |--> 1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 0.357851354407633)^2*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'ep:' -0.642126751353971*(-0.284297291184733*LN - log(LN)/log(2))/sqrt(LN)
# 'EP:' -1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(-0.321063375676986*sqrt(2)*(-0.284297291184733*LN - log(LN)/log(2))/sqrt(LN)) - sqrt(2)*sqrt(pi))/sqrt(pi)

# %%
BLER
# Out:
# [0.102689677840519, 0.00689536709410721]

# %%
BLER = [get_epsilon(EbNo_dB, 1/2)(LN=128) for EbNo_dB in range(1,10)]
BLER
# Out:
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'v:' (rho, z) |--> 1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 0.437211862241349)^2*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'ep:' -0.620938234882967*(-0.125576275517301*LN - log(LN)/log(2))/sqrt(LN)
# 'EP:' -1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(-0.310469117441483*sqrt(2)*(-0.125576275517301*LN - log(LN)/log(2))/sqrt(LN)) - sqrt(2)*sqrt(pi))/sqrt(pi)
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'v:' (rho, z) |--> 1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 0.357851354407633)^2*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'ep:' -0.642126751353971*(-0.284297291184733*LN - log(LN)/log(2))/sqrt(LN)
# 'EP:' -1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(-0.321063375676986*sqrt(2)*(-0.284297291184733*LN - log(LN)/log(2))/sqrt(LN)) - sqrt(2)*sqrt(pi))/sqrt(pi)
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'v:' (rho, z) |--> 1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 0.279339111333940)^2*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'ep:' -0.684126510564732*(-0.441321777332121*LN - log(LN)/log(2))/sqrt(LN)
# 'EP:' -1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(-0.342063255282366*sqrt(2)*(-0.441321777332121*LN - log(LN)/log(2))/sqrt(LN)) - sqrt(2)*sqrt(pi))/sqrt(pi)
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'v:' (rho, z) |--> 1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 0.205646583348871)^2*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'ep:' -0.755340537651215*(-0.588706833302257*LN - log(LN)/log(2))/sqrt(LN)
# 'EP:' -1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(-0.377670268825607*sqrt(2)*(-0.588706833302257*LN - log(LN)/log(2))/sqrt(LN)) - sqrt(2)*sqrt(pi))/sqrt(pi)
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'v:' (rho, z) |--> 1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 0.140805916250719)^2*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'ep:' -0.870394097075673*(-0.718388167498563*LN - log(LN)/log(2))/sqrt(LN)
# 'EP:' -1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(-0.435197048537836*sqrt(2)*(-0.718388167498563*LN - log(LN)/log(2))/sqrt(LN)) - sqrt(2)*sqrt(pi))/sqrt(pi)
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'v:' (rho, z) |--> 1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 0.0881195454128807)^2*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'ep:' -1.05581999459944*(-0.823760909174239*LN - log(LN)/log(2))/sqrt(LN)
# 'EP:' -1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(-0.527909997299721*sqrt(2)*(-0.823760909174239*LN - log(LN)/log(2))/sqrt(LN)) - sqrt(2)*sqrt(pi))/sqrt(pi)
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'v:' (rho, z) |--> 1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 0.0493188930742844)^2*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'ep:' -1.36249859166637*(-0.901362213851431*LN - log(LN)/log(2))/sqrt(LN)
# 'EP:' -1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(-0.681249295833186*sqrt(2)*(-0.901362213851431*LN - log(LN)/log(2))/sqrt(LN)) - sqrt(2)*sqrt(pi))/sqrt(pi)
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'v:' (rho, z) |--> 1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 0.0240200256171004)^2*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'ep:' -1.89503581682653*(-0.951959948765799*LN - log(LN)/log(2))/sqrt(LN)
# 'EP:' -1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(-0.947517908413267*sqrt(2)*(-0.951959948765799*LN - log(LN)/log(2))/sqrt(LN)) - sqrt(2)*sqrt(pi))/sqrt(pi)
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'c:' (rho, z) |--> -1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 1)*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'v:' (rho, z) |--> 1/2*sqrt(2)*(log(e^(2*sqrt(rho)*z - 2*rho) + 1)/log(2) - 0.00983640765654237)^2*e^(-1/2*z^2)/sqrt(pi)
# Graphics object consisting of 1 graphics primitive
# 'ep:' -2.88763254126212*(-0.980327184686915*LN - log(LN)/log(2))/sqrt(LN)
# 'EP:' -1/4*sqrt(2)*(sqrt(2)*sqrt(pi)*erf(-1.44381627063106*sqrt(2)*(-0.980327184686915*LN - log(LN)/log(2))/sqrt(LN)) - sqrt(2)*sqrt(pi))/sqrt(pi)
# [0.102689677840519,
#  0.00689536709410721,
#  0.0000617391099148046,
#  1.91782182912270e-8,
#  1.34336985979644e-14,
#  0,
#  0,
#  0,
#  0]

# %% [markdown]
# ## Simple Form

# %%
C = (1/2)*log(1+P,2)
