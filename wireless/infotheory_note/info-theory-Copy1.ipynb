# %%
from sage.all import *

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## LIB: entropy in wireless.infotheory

# %%
from wireless.infotheory import entropy

entropy.hello()
entropy.test_010()
# Out:
# Hi
# log(x)*p(x)

# %%
def H(p,x):
    """
    Caculate entropy of descrete random variable X
    """
    return -integrate(p(x)*log(p(x)),x)

def test_020():
    x = var('x')
    p = function('p')
    H(p,x)
    
test_020()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f2ace818d4a0> in <module>()
#      10     H(p,x)
#      11
# ---> 12 test_020()
#
# <ipython-input-25-f2ace818d4a0> in test_020()
#       8     x = var('x')
#       9     p = function('p')
# ---> 10     H(p,x)
#      11
#      12 test_020()
#
# <ipython-input-25-f2ace818d4a0> in H(p, x)
#       3     Caculate entropy of descrete random variable X
#       4     """
# ----> 5     return -integrate(p(x)*log(p(x)),x)
#       6
#       7 def test_020():
#
# /home/sjkim/anaconda3/envs/sage/lib/python3.7/site-packages/sage/misc/functional.py in integral(x, *args, **kwds)
#     751     """
#     752     if hasattr(x, 'integral'):
# --> 753         return x.integral(*args, **kwds)
#     754     else:
#     755         from sage.symbolic.ring import SR
#
# ...

# %%
p = function('p')
p
# Out:
# p

# %%
pretty_print(p)
# Out:
# p

# %%
x = var(x)
integral(x, x)
# Out:
# 1/2*x^2

# %%
p = function('p')
integrate(p(x),x)
# Out:
# integrate(p(x), x)

# %%
integrate(x, x)
# Out:
# 1/2*x^2

# %%
integrate(p(x)*log(p(x)),x) #-integrate(p(x)*log(p(x)),x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-2b334b362a9e> in <module>()
# ----> 1 integrate(p(x)*log(p(x)),x) #-integrate(p(x)*log(p(x)),x)
#
# /home/sjkim/anaconda3/envs/sage/lib/python3.7/site-packages/sage/misc/functional.py in integral(x, *args, **kwds)
#     751     """
#     752     if hasattr(x, 'integral'):
# --> 753         return x.integral(*args, **kwds)
#     754     else:
#     755         from sage.symbolic.ring import SR
#
# /home/sjkim/anaconda3/envs/sage/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.integral (build/cythonized/sage/symbolic/expression.cpp:64575)()
#   12389                     R = ring.SR
#   12390             return R(integral(f, v, a, b, **kwds))
# > 12391         return integral(self, *args, **kwds)
#   12392
#   12393     integrate = integral
#
# ...

# %%
integrate(log(p(x)),x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-21d6fc22b3d5> in <module>()
# ----> 1 integrate(log(p(x)),x)
#
# /home/sjkim/anaconda3/envs/sage/lib/python3.7/site-packages/sage/misc/functional.py in integral(x, *args, **kwds)
#     751     """
#     752     if hasattr(x, 'integral'):
# --> 753         return x.integral(*args, **kwds)
#     754     else:
#     755         from sage.symbolic.ring import SR
#
# /home/sjkim/anaconda3/envs/sage/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.integral (build/cythonized/sage/symbolic/expression.cpp:64575)()
#   12389                     R = ring.SR
#   12390             return R(integral(f, v, a, b, **kwds))
# > 12391         return integral(self, *args, **kwds)
#   12392
#   12393     integrate = integral
#
# ...
