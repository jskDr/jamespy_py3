# %% [markdown]
# # 4 QAM with channel coding.
# I will consider classification in this code. Previously, I considered the problem as regression issue.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Layer, BatchNormalization
from tensorflow.keras import Sequential

import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

print(tf.__version__)

# %load_ext autoreload
# %autoreload 2

from wireless import ae
# Out:
# 2.1.0
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ae.ae_train_test(
N_mod_bits=1,
Code_K=1,
Code_N=2,
N_sample=1000,
N_episodes=100,
EbNo_dB=5)
# Out:
# (1000,) (1000, 2)
# Epoch: 0, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 1.0444815158843994 0.7549999952316284 0.24500000476837158
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.9743947982788086 0.7549999952316284 0.24500000476837158
# Epoch: 10, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.7174601554870605 0.8769999742507935 0.12300002574920654
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.682873010635376 0.8999999761581421 0.10000002384185791
# Epoch: 20, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.5294226408004761 0.9419999718666077 0.058000028133392334
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.7542270421981812 0.8999999761581421 0.10000002384185791
# Epoch: 30, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.24196462333202362 0.9670000076293945 0.03299999237060547
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.2701265513896942 0.9449999928474426 0.05500000715255737
# Epoch: 40, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.17837782204151154 0.9779999852180481 0.022000014781951904
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.1461361199617386 0.9750000238418579 0.02499997615814209
# Epoch: 50, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.2033749520778656 0.9879999756813049 0.012000024318695068
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.29789769649505615 0.9800000190734863 0.019999980926513672
# Epoch: 60, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.06990258395671844 0.996999979019165 0.003000020980834961
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.33911842107772827 0.9750000238418579 0.02499997615814209
# Epoch: 70, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.1411568820476532 0.9879999756813049 0.012000024318695068
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.08667503297328949 0.9900000095367432 0.009999990463256836
# Epoch: 80, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.06896896660327911 0.9929999709129333 0.00700002908706665
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.11224691569805145 0.9850000143051147 0.014999985694885254
# Epoch: 90, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.050994567573070526 0.9950000047683716 0.004999995231628418
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.03983278200030327 0.9950000047683716 0.004999995231628418
