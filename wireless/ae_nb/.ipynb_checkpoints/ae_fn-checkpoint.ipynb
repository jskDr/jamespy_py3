# %% [markdown]
# # BPSK with AE channel coding.
# I will consider classification in this code. Previously, I considered the problem as regression issue.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Layer, BatchNormalization
from tensorflow.keras import Sequential

import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

print(tf.__version__)

# %load_ext autoreload
# %autoreload 2

from wireless import ae
# Out:
# 2.1.0

# %%
ae.ae_train_test(
N_mod_bits=1,
Code_K=1,
Code_N=2,
N_sample=1000,
N_episodes=100,
EbNo_dB=5)
# Out:
# (1000,) (1000, 2)
# Epoch: 0, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 1.713535189628601 0.29374998807907104 0.706250011920929
# 테스트의 손실과 마지막 스텝 정확도, 오류: 1.3938624858856201 0.33500000834465027 0.6649999916553497
# Epoch: 10, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 1.3442507982254028 0.29899999499320984 0.7010000050067902
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.9990541934967041 0.3199999928474426 0.6800000071525574
# Epoch: 20, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 1.0773260593414307 0.32199999690055847 0.6780000030994415
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.9600688219070435 0.36000001430511475 0.6399999856948853
# Epoch: 30, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.8845239877700806 0.3529999852180481 0.6470000147819519
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.8690541982650757 0.33500000834465027 0.6649999916553497
# Epoch: 40, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.6839224100112915 0.4790000021457672 0.5209999978542328
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.6342489719390869 0.49000000953674316 0.5099999904632568
# Epoch: 50, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.7119734287261963 0.5730000138282776 0.4269999861717224
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.6214503049850464 0.6100000143051147 0.38999998569488525
# Epoch: 60, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.6459493637084961 0.6620000004768372 0.33799999952316284
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.6814075708389282 0.6000000238418579 0.3999999761581421
# Epoch: 70, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.552336573600769 0.7519999742507935 0.24800002574920654
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.5728372931480408 0.7400000095367432 0.25999999046325684
# Epoch: 80, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.48089316487312317 0.828000009059906 0.171999990940094
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.5989590287208557 0.7799999713897705 0.2200000286102295
# Epoch: 90, 트레이닝의 손실과 마지막 스텝 정확도, 오류: 0.40631747245788574 0.8930000066757202 0.10699999332427979
# 테스트의 손실과 마지막 스텝 정확도, 오류: 0.3904179632663727 0.8999999761581421 0.10000002384185791
