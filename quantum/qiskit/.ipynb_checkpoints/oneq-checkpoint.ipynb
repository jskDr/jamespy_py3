# %%
# %load_ext autoreload
# %autoreload 2
from IPython.display import display

from qiskit import QuantumCircuit, assemble, Aer
from math import pi, sqrt
from qiskit.visualization import plot_bloch_multivector, plot_histogram

import myqiskit as mq
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
### X-gate only

# %%
qc = QuantumCircuit(1)
qc.x(0)
display(qc.draw())
mq.show_bloch(qc)

# %% [markdown]
# ### Z-gate only

# %%
qc = QuantumCircuit(1)
qc.z(0)
display(qc.draw())
mq.show_bloch(qc)

# %% [markdown]
# ### H-gate & Z-gate

# %%
qc = QuantumCircuit(1)
qc.h(0)
display(qc.draw())
display(mq.show_bloch(qc))
qc.z(0)
display(qc.draw())
mq.show_bloch(qc)

# %% [markdown]
# ### Y-gate only

# %%
qc = QuantumCircuit(1)
qc.y(0)
display(qc.draw())
mq.show_bloch(qc)

# %%
### H-gate and Y-gate

# %%
qc = QuantumCircuit(1)
qc.h(0)
display(qc.draw())
display(mq.show_bloch(qc))
qc.y(0)
display(qc.draw())
mq.show_bloch(qc)

# %% [markdown]
# ## X_measurement

# %% [markdown]
# ### Initialization with [1/sqrt(2), -1/sqrt(2)]

# %%
def x_measurement(qc, qubit, cbit):
    qc.h(qubit)
    qc.measure(qubit, cbit)
    return qc

initial_state = [1/sqrt(2), -1/sqrt(2)]
qc = QuantumCircuit(1,1)
qc.initialize(initial_state, 0)
x_measurement(qc, 0, 0)
display(qc.draw())
mq.show_hist(qc)

# %% [markdown]
# ### No initialization: H-X-H

# %%
def x_measurement(qc, qubit, cbit):
    qc.h(qubit)
    qc.measure(qubit, cbit)
    return qc

#initial_state = [1/sqrt(2), -1/sqrt(2)]
qc = QuantumCircuit(1,1)
#qc.initialize(initial_state, 0)
qc.h(0)
qc.x(0)
x_measurement(qc, 0, 0)
display(qc.draw())
mq.show_hist(qc)

# %% [markdown]
# ### No initialization: H-H

# %%
def x_measurement(qc, qubit, cbit):
    qc.h(qubit)
    qc.measure(qubit, cbit)
    return qc

#initial_state = [1/sqrt(2), -1/sqrt(2)]
qc = QuantumCircuit(1,1)
#qc.initialize(initial_state, 0)
qc.h(0)
#qc.x(0)
x_measurement(qc, 0, 0)
display(qc.draw())
mq.show_hist(qc)

# %%
def x_measurement(qc, qubit, cbit):
    qc.h(qubit)
    qc.measure(qubit, cbit)
    return qc

#initial_state = [1/sqrt(2), -1/sqrt(2)]
qc = QuantumCircuit(1,1)
#qc.initialize(initial_state, 0)
#qc.h(0)
#qc.x(0)
x_measurement(qc, 0, 0)
display(qc.draw())
mq.show_hist(qc)

# %% [markdown]
# ### Direct measurement

# %%
qc = QuantumCircuit(1,1)
qc.measure(0, 0)
display(qc.draw())
mq.show_hist(qc)

# %% [markdown]
# ### Direct measurement: H-gate

# %%
qc = QuantumCircuit(1,1)
qc.h(0)
qc.measure(0, 0)
display(qc.draw())
mq.show_hist(qc)

# %%
qc = QuantumCircuit(1,1)
qc.initialize([0.9, sqrt(1-0.9**2)], 0)
qc.measure(0, 0)
display(qc.draw())
mq.show_hist(qc)
